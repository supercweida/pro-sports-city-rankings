# %%
# importing pandas as pd
import pandas as pd
  
# read an excel file and convert 
# into a dataframe object
champs = pd.DataFrame(pd.read_excel("Pro Sports Champions Since I Was Born.xlsx"))
  
# show the dataframe
champs
# Out:
#             State         City   Metro Area League  Season  \
# 0   Massachusetts   Foxborough       Boston    NFL    2001
# 1         Florida        Tampa        Tampa    NFL    2002
# 2   Massachusetts   Foxborough       Boston    NFL    2003
# 3   Massachusetts   Foxborough       Boston    NFL    2004
# 4    Pennslyvania   Pittsburgh   Pittsburgh    NFL    2005
# ..            ...          ...          ...    ...     ...
# 81       Missouri    St. Louis     St.Louis    NHL    2019
# 82        Florida        Tampa        Tampa    NHL    2020
# 83        Florida        Tampa        Tampa    NHL    2021
# 84       Colorado       Denver       Denver    NHL    2022
# 85       Missouri  Kansas City  Kansas City    NFL    2022
#
#                     Team
# 0   New England Patriots
# 1   Tampa Bay Buccaneers
# 2   New England Patriots
# 3   New England Patriots
# 4    Pittsburgh Steelers
# ..                   ...
# 81       St. Louis Blues
# 82   Tampa Bay Lightning
# ...

# %%
mvps = pd.DataFrame(pd.read_excel("Pro Sports MVPs Since I Was Born.xlsx"))
mvps
# Out:
#                 Year(s)                              NFL  \
# 0                  2001                                X
# 1   2001-02-01 00:00:00                      Kurt Warner
# 2   2002-03-01 00:00:00                      Rich Gannon
# 3   2003-04-01 00:00:00  Peyton Manning and Steve McNair
# 4   2004-05-01 00:00:00                   Peyton Manning
# 5   2005-06-01 00:00:00                  Shaun Alexander
# 6   2006-07-01 00:00:00              LaDainian Tomlinson
# 7   2007-08-01 00:00:00                        Tom Brady
# 8   2008-09-01 00:00:00                   Peyton Manning
# 9   2009-10-01 00:00:00                   Peyton Manning
# 10  2010-11-01 00:00:00                        Tom Brady
# 11  2011-12-01 00:00:00                    Aaron Rodgers
# 12              2012-13                  Adrian Peterson
# 13              2013-14                   Peyton Manning
# 14              2014-15                    Aaron Rodgers
# ...

# %%
wisco = pd.DataFrame(pd.read_excel("Wisconsin Pro Sports Yearly Outcomes Since I Was Born.xlsx"))
wisco
# Out:
#               Franchise    Milwaukee Brewers Unnamed: 2  \
# 0           Year/Season          Best Player     Record
# 1                  2001        Richie Sexson    68 - 94
# 2   2001-02-01 00:00:00        Richie Sexson   56 - 106
# 3   2002-03-01 00:00:00        Richie Sexson    68 - 94
# 4   2003-04-01 00:00:00           Danny Kolb    67 - 94
# 5   2004-05-01 00:00:00           Carlos Lee    81 - 81
# 6   2005-06-01 00:00:00        Chris Capuano    75 - 87
# 7   2006-07-01 00:00:00       Prince Fielder    83 - 79
# 8   2007-08-01 00:00:00          CC Sabathia    90 - 72
# 9   2008-09-01 00:00:00       Prince Fielder    80 - 82
# 10  2009-10-01 00:00:00           Ryan Braun    77 - 85
# 11  2010-11-01 00:00:00           Ryan Braun    96 - 66
# 12  2011-12-01 00:00:00           Ryan Braun    83 - 79
# 13              2012-13         Carlos Gomez    74 - 88
# 14              2013-14      Jonathan Lucroy    82 - 80
# 15              2014-15  Francisco Rodriguez    68 - 94
# ...

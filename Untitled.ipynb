# %%
import requests

url = "https://www.pro-football-reference.com/years/1994/index.htm"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html data-version="klecko-" data-root="/home/pfr/build" lang="en" class="no-js" >
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />
#     <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202410071" />
# <script>
# /* https://docs.osano.com/hc/en-us/articles/22469433444372-Google-Consent-Mode-v2  */
#   window.dataLayer = window.dataLayer ||[];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('consent','default',{
#         'ad_storage':'denied',
#         'analytics_storage':'denied',
#         'ad_user_data':'denied',
#         'ad_personalization':'denied',
#         'personalization_storage':'denied',
#         'functionality_storage':'granted',
#         'security_storage':'granted',
#         'wait_for_update': 500
#       });
#       gtag("set", "ads_data_redaction", true);
# </script>
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.text, 'html.parser')

stats_table = soup.find('table', {'id': 'stats_game_log'})

# %%
for row in stats_table.find_all('tr')[1:]:  # Skip header row

    cells = row.find_all('td')

    # Extract relevant data from cells (e.g., date, tackles, interceptions) 

    player_stats.append({ 

        'date': cells[0].text,

        'tackles': cells[1].text,

        'interceptions': cells[2].text,

        # ... add more stats as needed

    })
